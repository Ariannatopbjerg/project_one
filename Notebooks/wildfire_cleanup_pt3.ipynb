# %%
import pandas as pd
# Import our input dataset
fire_df = pd.read_csv('../Resources/wildfire_v2_clean_data.csv')
fire_df.head()
# Out:
#    fire_size fire_size_class         fire_cause   latitude   longitude state  \
# 0       10.0               C  Missing/Undefined  18.105072  -66.753044    PR
# 1        3.0               B              Arson  35.038330  -87.610000    TN
# 2       60.0               C              Arson  34.947800  -88.722500    MS
# 3        1.0               B     Debris Burning  39.641400 -119.308300    NV
# 4        2.0               B      Miscellaneous  30.700600  -90.591400    LA
#
#   discovery_month discovery_date  discovery_year  Vegetation  ...  Wind_cont  \
# 0             Feb      1/12/2007            2007          12  ...   3.250413
# 1             Dec     11/11/2006            2006          15  ...   2.122320
# 2             Feb      1/30/2004            2004          16  ...   3.369050
# 3             Jun       5/7/2005            2005           0  ...   0.000000
# 4             Sep      8/23/1999            1999          12  ...  -1.000000
#
#    Hum_pre_30  Hum_pre_15  Hum_pre_7   Hum_cont  Prec_pre_30  Prec_pre_15  \
# 0   78.216590   76.793750  76.381579  78.724370          0.0          0.0
# 1   70.840000   65.858911  55.505882  81.682678         59.8          8.4
# 2   75.531629   75.868613  76.812834  65.063800        168.8         42.2
# 3   44.778429   37.140811  35.353846   0.000000         10.4          7.2
# 4   -1.000000   -1.000000  -1.000000  -1.000000         -1.0         -1.0
#
#    Prec_pre_7  Prec_cont  remoteness
# 0         0.0        0.0    0.017923
# 1         0.0       86.8    0.184355
# 2        18.1      124.5    0.194544
# 3         0.0        0.0    0.487447
# 4        -1.0       -1.0    0.214633
#
# [5 rows x 28 columns]

# %%
fire_df.columns
# Out:
# Index(['fire_size', 'fire_size_class', 'fire_cause', 'latitude', 'longitude',
#        'state', 'discovery_month', 'discovery_date', 'discovery_year',
#        'Vegetation', 'fire_mag', 'Temp_pre_30', 'Temp_pre_15', 'Temp_pre_7',
#        'Temp_cont', 'Wind_pre_30', 'Wind_pre_15', 'Wind_pre_7', 'Wind_cont',
#        'Hum_pre_30', 'Hum_pre_15', 'Hum_pre_7', 'Hum_cont', 'Prec_pre_30',
#        'Prec_pre_15', 'Prec_pre_7', 'Prec_cont', 'remoteness'],
#       dtype='object')

# %%
fire_df.drop(['remoteness'], axis=1, inplace=True)
fire_df.head()
# Out:
#    fire_size fire_size_class         fire_cause   latitude   longitude state  \
# 0       10.0               C  Missing/Undefined  18.105072  -66.753044    PR
# 1        3.0               B              Arson  35.038330  -87.610000    TN
# 2       60.0               C              Arson  34.947800  -88.722500    MS
# 3        1.0               B     Debris Burning  39.641400 -119.308300    NV
# 4        2.0               B      Miscellaneous  30.700600  -90.591400    LA
#
#   discovery_month discovery_date  discovery_year  Vegetation  ...  Wind_pre_7  \
# 0             Feb      1/12/2007            2007          12  ...    3.262092
# 1             Dec     11/11/2006            2006          15  ...    1.976471
# 2             Feb      1/30/2004            2004          16  ...    2.695833
# 3             Jun       5/7/2005            2005           0  ...    3.671282
# 4             Sep      8/23/1999            1999          12  ...   -1.000000
#
#    Wind_cont  Hum_pre_30  Hum_pre_15  Hum_pre_7   Hum_cont  Prec_pre_30  \
# 0   3.250413   78.216590   76.793750  76.381579  78.724370          0.0
# 1   2.122320   70.840000   65.858911  55.505882  81.682678         59.8
# 2   3.369050   75.531629   75.868613  76.812834  65.063800        168.8
# 3   0.000000   44.778429   37.140811  35.353846   0.000000         10.4
# 4  -1.000000   -1.000000   -1.000000  -1.000000  -1.000000         -1.0
#
#    Prec_pre_15  Prec_pre_7  Prec_cont
# 0          0.0         0.0        0.0
# 1          8.4         0.0       86.8
# 2         42.2        18.1      124.5
# 3          7.2         0.0        0.0
# 4         -1.0        -1.0       -1.0
#
# [5 rows x 27 columns]

# %%
fire_df.rename(columns={'fire_size':'Fire_Size', 
                        'fire_size_class':'Fire_Size_Class', 
                        'fire_cause':'Fire_Cause', 
                        'fire_size_class':'Fire_Size_Class', 
                        'latitude':'Latitude', 
                        'longitude':'Longitude', 
                        'state':'State',
                        'discovery_month':'Discovery_Month',
                        'discovery_date':'Discovery_Date',
                        'discovery_year':'Discovery_Year',
                        'fire_mag':'Fire_Magnitude',
                        'Temp_pre_30':'Temp_Pre_30',
                        'Temp_pre_15':'Temp_Pre_15',
                        'Temp_pre_7':'Temp_Pre_7',
                        'Temp_cont':'Temp_Present',
                        'Wind_pre_30':'Wind_Pre_30',
                        'Wind_pre_15':'Wind_Pre_15',
                        'Wind_pre_7':'Wind_Pre_7',
                        'Wind_cont':'Wind_Present',
                        'Hum_pre_30':'Hum_Pre_30',
                        'Hum_pre_15':'Hum_Pre_15',
                        'Hum_pre_7':'Hum_Pre_7',
                        'Hum_cont':'Hum_Present',
                        'Prec_pre_30':'Prec_Pre_30',
                        'Prec_pre_15':'Prec_Pre_15',
                        'Prec_pre_7':'Prec_Pre_7',
                        'Prec_cont':'Prec_Present'}, inplace=True)
fire_df.head()
# Out:
#    Fire_Size Fire_Size_Class         Fire_Cause   Latitude   Longitude State  \
# 0       10.0               C  Missing/Undefined  18.105072  -66.753044    PR
# 1        3.0               B              Arson  35.038330  -87.610000    TN
# 2       60.0               C              Arson  34.947800  -88.722500    MS
# 3        1.0               B     Debris Burning  39.641400 -119.308300    NV
# 4        2.0               B      Miscellaneous  30.700600  -90.591400    LA
#
#   Discovery_Month Discovery_Date  Discovery_Year  Vegetation  ...  Wind_Pre_7  \
# 0             Feb      1/12/2007            2007          12  ...    3.262092
# 1             Dec     11/11/2006            2006          15  ...    1.976471
# 2             Feb      1/30/2004            2004          16  ...    2.695833
# 3             Jun       5/7/2005            2005           0  ...    3.671282
# 4             Sep      8/23/1999            1999          12  ...   -1.000000
#
#    Wind_Present  Hum_Pre_30  Hum_Pre_15  Hum_Pre_7  Hum_Present  Prec_Pre_30  \
# 0      3.250413   78.216590   76.793750  76.381579    78.724370          0.0
# 1      2.122320   70.840000   65.858911  55.505882    81.682678         59.8
# 2      3.369050   75.531629   75.868613  76.812834    65.063800        168.8
# 3      0.000000   44.778429   37.140811  35.353846     0.000000         10.4
# 4     -1.000000   -1.000000   -1.000000  -1.000000    -1.000000         -1.0
#
#    Prec_Pre_15  Prec_Pre_7  Prec_Present
# 0          0.0         0.0           0.0
# 1          8.4         0.0          86.8
# 2         42.2        18.1         124.5
# 3          7.2         0.0           0.0
# 4         -1.0        -1.0          -1.0
#
# [5 rows x 27 columns]

# %%
fire_df.to_csv('../Resources/wildfire_data_final.csv', index=False)
